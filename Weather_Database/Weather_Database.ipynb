# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a new set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weatherdesc = city_weather['weather'][0]['description']
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_weatherdesc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port macquarie
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | fairbanks
# Processing Record 5 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | grand gaube
# Processing Record 8 of Set 1 | komsomolskiy
# Processing Record 9 of Set 1 | sao miguel do araguaia
# Processing Record 10 of Set 1 | norman wells
# Processing Record 11 of Set 1 | abrau-dyurso
# Processing Record 12 of Set 1 | pitimbu
# Processing Record 13 of Set 1 | luderitz
# Processing Record 14 of Set 1 | vanimo
# Processing Record 15 of Set 1 | fortuna
# Processing Record 16 of Set 1 | jaynagar-majilpur
# Processing Record 17 of Set 1 | kahului
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | salalah
# Processing Record 20 of Set 1 | broome
# Processing Record 21 of Set 1 | qaanaaq
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | pathein
# Processing Record 24 of Set 1 | alofi
# Processing Record 25 of Set 1 | amnat charoen
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | khandyga
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | comodoro rivadavia
# Processing Record 31 of Set 1 | majene
# Processing Record 32 of Set 1 | bubaque
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | senno
# Processing Record 35 of Set 1 | ixtapa
# Processing Record 36 of Set 1 | praia da vitoria
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | neiafu
# Processing Record 39 of Set 1 | ballina
# Processing Record 40 of Set 1 | ucluelet
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | tarare
# Processing Record 44 of Set 1 | skjervoy
# Processing Record 45 of Set 1 | codrington
# Processing Record 46 of Set 1 | sinnamary
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | kenitra
# Processing Record 50 of Set 1 | college
# Processing Record 1 of Set 2 | belmonte
# Processing Record 2 of Set 2 | veraval
# Processing Record 3 of Set 2 | batagay-alyta
# Processing Record 4 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 2 | poum
# Processing Record 6 of Set 2 | pathalgaon
# Processing Record 7 of Set 2 | lobatse
# Processing Record 8 of Set 2 | richards bay
# Processing Record 9 of Set 2 | rimavska sobota
# Processing Record 10 of Set 2 | reconquista
# Processing Record 11 of Set 2 | banda aceh
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | rocha
# Processing Record 14 of Set 2 | dunedin
# Processing Record 15 of Set 2 | tasiilaq
# Processing Record 16 of Set 2 | luz
# Processing Record 17 of Set 2 | anadyr
# Processing Record 18 of Set 2 | concordia
# Processing Record 19 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 2 | hithadhoo
# Processing Record 21 of Set 2 | havoysund
# Processing Record 22 of Set 2 | cairns
# Processing Record 23 of Set 2 | lima
# Processing Record 24 of Set 2 | sawakin
# Processing Record 25 of Set 2 | leningradskiy
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | beloha
# Processing Record 28 of Set 2 | awjilah
# Processing Record 29 of Set 2 | pangody
# Processing Record 30 of Set 2 | new norfolk
# Processing Record 31 of Set 2 | tautira
# Processing Record 32 of Set 2 | ust-tsilma
# Processing Record 33 of Set 2 | puerto escondido
# Processing Record 34 of Set 2 | nioro
# Processing Record 35 of Set 2 | camacha
# Processing Record 36 of Set 2 | katsuura
# Processing Record 37 of Set 2 | khash
# Processing Record 38 of Set 2 | bluff
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | juquitiba
# Processing Record 41 of Set 2 | windsor locks
# Processing Record 42 of Set 2 | barrow
# Processing Record 43 of Set 2 | evensk
# Processing Record 44 of Set 2 | san cristobal
# Processing Record 45 of Set 2 | berlevag
# Processing Record 46 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 2 | nome
# Processing Record 48 of Set 2 | giyon
# Processing Record 49 of Set 2 | kaeo
# Processing Record 50 of Set 2 | dikson
# Processing Record 1 of Set 3 | makat
# Processing Record 2 of Set 3 | upernavik
# Processing Record 3 of Set 3 | dalvik
# Processing Record 4 of Set 3 | pagudpud
# Processing Record 5 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 3 | lyuban
# Processing Record 7 of Set 3 | thompson
# Processing Record 8 of Set 3 | candawaga
# City not found. Skipping...
# Processing Record 9 of Set 3 | gizo
# Processing Record 10 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 3 | vostok
# Processing Record 12 of Set 3 | lebu
# Processing Record 13 of Set 3 | jamestown
# Processing Record 14 of Set 3 | oussouye
# Processing Record 15 of Set 3 | hermanus
# Processing Record 16 of Set 3 | ust-uda
# Processing Record 17 of Set 3 | la ronge
# Processing Record 18 of Set 3 | adrar
# Processing Record 19 of Set 3 | bati
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | coruripe
# Processing Record 22 of Set 3 | yellowknife
# Processing Record 23 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 26 of Set 3 | busselton
# Processing Record 27 of Set 3 | ostrovnoy
# Processing Record 28 of Set 3 | lagos
# Processing Record 29 of Set 3 | sitka
# Processing Record 30 of Set 3 | atuona
# Processing Record 31 of Set 3 | svetlyy
# Processing Record 32 of Set 3 | nowy dwor gdanski
# Processing Record 33 of Set 3 | tuktoyaktuk
# Processing Record 34 of Set 3 | mahebourg
# Processing Record 35 of Set 3 | nikolskoye
# Processing Record 36 of Set 3 | pacific grove
# Processing Record 37 of Set 3 | tura
# Processing Record 38 of Set 3 | naifaru
# Processing Record 39 of Set 3 | kruisfontein
# Processing Record 40 of Set 3 | emba
# Processing Record 41 of Set 3 | faanui
# Processing Record 42 of Set 3 | ginda
# Processing Record 43 of Set 3 | paamiut
# Processing Record 44 of Set 3 | loa janan
# Processing Record 45 of Set 3 | lata
# Processing Record 46 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 47 of Set 3 | carnarvon
# Processing Record 48 of Set 3 | hobyo
# Processing Record 49 of Set 3 | port augusta
# Processing Record 50 of Set 3 | pedra
# Processing Record 1 of Set 4 | rundu
# Processing Record 2 of Set 4 | chifeng
# Processing Record 3 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 4 | ribeira grande
# Processing Record 5 of Set 4 | constitucion
# Processing Record 6 of Set 4 | katherine
# Processing Record 7 of Set 4 | la llanada
# Processing Record 8 of Set 4 | malangwa
# Processing Record 9 of Set 4 | paracelis
# Processing Record 10 of Set 4 | catuday
# Processing Record 11 of Set 4 | meulaboh
# Processing Record 12 of Set 4 | cochrane
# Processing Record 13 of Set 4 | pimentel
# Processing Record 14 of Set 4 | saltabarranca
# Processing Record 15 of Set 4 | kabompo
# Processing Record 16 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 4 | tucuman
# Processing Record 18 of Set 4 | miramar
# Processing Record 19 of Set 4 | cherusti
# Processing Record 20 of Set 4 | plettenberg bay
# Processing Record 21 of Set 4 | kurchum
# Processing Record 22 of Set 4 | sinop
# Processing Record 23 of Set 4 | havre-saint-pierre
# Processing Record 24 of Set 4 | severo-kurilsk
# Processing Record 25 of Set 4 | ambulu
# Processing Record 26 of Set 4 | byron bay
# Processing Record 27 of Set 4 | talisay
# Processing Record 28 of Set 4 | warragul
# Processing Record 29 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 4 | west wendover
# Processing Record 31 of Set 4 | pinawa
# Processing Record 32 of Set 4 | chokurdakh
# Processing Record 33 of Set 4 | aykino
# Processing Record 34 of Set 4 | kurilsk
# Processing Record 35 of Set 4 | tiksi
# Processing Record 36 of Set 4 | ilulissat
# Processing Record 37 of Set 4 | ust-maya
# Processing Record 38 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 39 of Set 4 | karratha
# Processing Record 40 of Set 4 | zhangye
# Processing Record 41 of Set 4 | tezu
# Processing Record 42 of Set 4 | grindavik
# Processing Record 43 of Set 4 | hilo
# Processing Record 44 of Set 4 | buala
# Processing Record 45 of Set 4 | yaan
# Processing Record 46 of Set 4 | provideniya
# Processing Record 47 of Set 4 | castro
# Processing Record 48 of Set 4 | longyearbyen
# Processing Record 49 of Set 4 | whitehorse
# Processing Record 50 of Set 4 | guerrero negro
# Processing Record 1 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 5 | dingle
# Processing Record 3 of Set 5 | am timan
# Processing Record 4 of Set 5 | hofn
# Processing Record 5 of Set 5 | yerbogachen
# Processing Record 6 of Set 5 | huanren
# Processing Record 7 of Set 5 | ponta do sol
# Processing Record 8 of Set 5 | saint george
# Processing Record 9 of Set 5 | ilembo
# Processing Record 10 of Set 5 | magole
# Processing Record 11 of Set 5 | lazurne
# Processing Record 12 of Set 5 | uwajima
# Processing Record 13 of Set 5 | stokmarknes
# Processing Record 14 of Set 5 | shiyan
# Processing Record 15 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 5 | nouadhibou
# Processing Record 17 of Set 5 | ravar
# Processing Record 18 of Set 5 | ledyard
# Processing Record 19 of Set 5 | esperance
# Processing Record 20 of Set 5 | omboue
# Processing Record 21 of Set 5 | lompoc
# Processing Record 22 of Set 5 | lorengau
# Processing Record 23 of Set 5 | marystown
# Processing Record 24 of Set 5 | harper
# Processing Record 25 of Set 5 | kathmandu
# Processing Record 26 of Set 5 | sayanskiy
# City not found. Skipping...
# Processing Record 27 of Set 5 | puerto colombia
# Processing Record 28 of Set 5 | nouakchott
# Processing Record 29 of Set 5 | gimli
# Processing Record 30 of Set 5 | saldanha
# Processing Record 31 of Set 5 | bafoulabe
# Processing Record 32 of Set 5 | alakurtti
# Processing Record 33 of Set 5 | inirida
# Processing Record 34 of Set 5 | bandarbeyla
# Processing Record 35 of Set 5 | nabire
# Processing Record 36 of Set 5 | kushima
# Processing Record 37 of Set 5 | narsaq
# Processing Record 38 of Set 5 | arraial do cabo
# Processing Record 39 of Set 5 | acapulco
# Processing Record 40 of Set 5 | iqaluit
# Processing Record 41 of Set 5 | balkanabat
# Processing Record 42 of Set 5 | santa cruz
# Processing Record 43 of Set 5 | souillac
# Processing Record 44 of Set 5 | macas
# Processing Record 45 of Set 5 | touros
# Processing Record 46 of Set 5 | langxiang
# Processing Record 47 of Set 5 | cabo san lucas
# Processing Record 48 of Set 5 | samarinda
# Processing Record 49 of Set 5 | tiznit
# Processing Record 50 of Set 5 | mackay
# Processing Record 1 of Set 6 | irece
# Processing Record 2 of Set 6 | kyakhta
# Processing Record 3 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 6 | bengkulu
# Processing Record 5 of Set 6 | batticaloa
# Processing Record 6 of Set 6 | srednekolymsk
# Processing Record 7 of Set 6 | airai
# Processing Record 8 of Set 6 | najran
# Processing Record 9 of Set 6 | saint-pierre
# Processing Record 10 of Set 6 | khilok
# Processing Record 11 of Set 6 | dukat
# Processing Record 12 of Set 6 | jadu
# Processing Record 13 of Set 6 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 14 of Set 6 | havre
# Processing Record 15 of Set 6 | shenjiamen
# Processing Record 16 of Set 6 | maldonado
# Processing Record 17 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 18 of Set 6 | pallasovka
# Processing Record 19 of Set 6 | dubai
# Processing Record 20 of Set 6 | muros
# Processing Record 21 of Set 6 | vardo
# Processing Record 22 of Set 6 | cherskiy
# Processing Record 23 of Set 6 | liwale
# Processing Record 24 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 6 | bakchar
# Processing Record 26 of Set 6 | burnie
# Processing Record 27 of Set 6 | port hardy
# Processing Record 28 of Set 6 | lagoa
# Processing Record 29 of Set 6 | kathu
# Processing Record 30 of Set 6 | jijiang
# Processing Record 31 of Set 6 | mount gambier
# Processing Record 32 of Set 6 | atikokan
# Processing Record 33 of Set 6 | khartoum
# Processing Record 34 of Set 6 | ust-kuyga
# Processing Record 35 of Set 6 | aparecida do taboado
# Processing Record 36 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 6 | malatya
# Processing Record 38 of Set 6 | hattiesburg
# Processing Record 39 of Set 6 | kirakira
# Processing Record 40 of Set 6 | bambous virieux
# Processing Record 41 of Set 6 | zeya
# Processing Record 42 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 6 | pekan
# Processing Record 44 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 45 of Set 6 | aybak
# City not found. Skipping...
# Processing Record 46 of Set 6 | cidreira
# Processing Record 47 of Set 6 | geraldton
# Processing Record 48 of Set 6 | damietta
# Processing Record 49 of Set 6 | mankono
# Processing Record 50 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 7 | novo horizonte
# Processing Record 2 of Set 7 | oranjestad
# Processing Record 3 of Set 7 | deputatskiy
# Processing Record 4 of Set 7 | nerchinsk
# Processing Record 5 of Set 7 | trinidad
# Processing Record 6 of Set 7 | baykit
# Processing Record 7 of Set 7 | khatanga
# Processing Record 8 of Set 7 | nichinan
# Processing Record 9 of Set 7 | maceio
# Processing Record 10 of Set 7 | tabas
# Processing Record 11 of Set 7 | san lawrenz
# Processing Record 12 of Set 7 | shakawe
# Processing Record 13 of Set 7 | hecun
# Processing Record 14 of Set 7 | kupang
# Processing Record 15 of Set 7 | kodiak
# Processing Record 16 of Set 7 | araouane
# Processing Record 17 of Set 7 | yakeshi
# Processing Record 18 of Set 7 | tapes
# Processing Record 19 of Set 7 | haines junction
# Processing Record 20 of Set 7 | crib point
# Processing Record 21 of Set 7 | kavaratti
# Processing Record 22 of Set 7 | novovarshavka
# Processing Record 23 of Set 7 | kuching
# Processing Record 24 of Set 7 | derzhavinsk
# Processing Record 25 of Set 7 | manzil salim
# Processing Record 26 of Set 7 | milkovo
# Processing Record 27 of Set 7 | tuatapere
# Processing Record 28 of Set 7 | ingham
# Processing Record 29 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 7 | khandbari
# Processing Record 31 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 7 | riyadh
# Processing Record 33 of Set 7 | moose factory
# Processing Record 34 of Set 7 | ati
# Processing Record 35 of Set 7 | cap malheureux
# Processing Record 36 of Set 7 | taoudenni
# Processing Record 37 of Set 7 | guantanamo
# Processing Record 38 of Set 7 | saint-francois
# Processing Record 39 of Set 7 | port hedland
# Processing Record 40 of Set 7 | tieli
# Processing Record 41 of Set 7 | eyemouth
# Processing Record 42 of Set 7 | ancud
# Processing Record 43 of Set 7 | tual
# Processing Record 44 of Set 7 | brae
# Processing Record 45 of Set 7 | mnogovershinnyy
# Processing Record 46 of Set 7 | rahden
# Processing Record 47 of Set 7 | viedma
# Processing Record 48 of Set 7 | mattru
# Processing Record 49 of Set 7 | prince rupert
# Processing Record 50 of Set 7 | pevek
# Processing Record 1 of Set 8 | palana
# Processing Record 2 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 8 | okhotsk
# Processing Record 4 of Set 8 | kidal
# Processing Record 5 of Set 8 | nanortalik
# Processing Record 6 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 7 of Set 8 | santa ana
# Processing Record 8 of Set 8 | goderich
# Processing Record 9 of Set 8 | kodinsk
# Processing Record 10 of Set 8 | rassvet
# Processing Record 11 of Set 8 | auki
# Processing Record 12 of Set 8 | ternate
# Processing Record 13 of Set 8 | ambilobe
# Processing Record 14 of Set 8 | ust-nera
# Processing Record 15 of Set 8 | east london
# Processing Record 16 of Set 8 | yulara
# Processing Record 17 of Set 8 | tyup
# Processing Record 18 of Set 8 | sistranda
# Processing Record 19 of Set 8 | tvoroyri
# Processing Record 20 of Set 8 | zhelyabovka
# Processing Record 21 of Set 8 | guadalupe y calvo
# Processing Record 22 of Set 8 | katangli
# Processing Record 23 of Set 8 | dombarovskiy
# Processing Record 24 of Set 8 | sofiysk
# City not found. Skipping...
# Processing Record 25 of Set 8 | lanester
# Processing Record 26 of Set 8 | high level
# Processing Record 27 of Set 8 | laguna
# Processing Record 28 of Set 8 | bourail
# Processing Record 29 of Set 8 | nuuk
# Processing Record 30 of Set 8 | phangnga
# Processing Record 31 of Set 8 | cayenne
# Processing Record 32 of Set 8 | hervey bay
# Processing Record 33 of Set 8 | sisophon
# Processing Record 34 of Set 8 | celestun
# Processing Record 35 of Set 8 | suileng
# Processing Record 36 of Set 8 | paka
# Processing Record 37 of Set 8 | boende
# Processing Record 38 of Set 8 | mucuri
# Processing Record 39 of Set 8 | chicama
# Processing Record 40 of Set 8 | talesh
# City not found. Skipping...
# Processing Record 41 of Set 8 | onega
# Processing Record 42 of Set 8 | matara
# Processing Record 43 of Set 8 | qom
# Processing Record 44 of Set 8 | naron
# Processing Record 45 of Set 8 | yar-sale
# Processing Record 46 of Set 8 | carutapera
# Processing Record 47 of Set 8 | santa marta
# Processing Record 48 of Set 8 | anzio
# Processing Record 49 of Set 8 | fernley
# Processing Record 50 of Set 8 | filadelfia
# Processing Record 1 of Set 9 | okha
# Processing Record 2 of Set 9 | abha
# Processing Record 3 of Set 9 | cocorit
# Processing Record 4 of Set 9 | talnakh
# Processing Record 5 of Set 9 | padang
# Processing Record 6 of Set 9 | dolzhanskaya
# Processing Record 7 of Set 9 | miandrivazo
# Processing Record 8 of Set 9 | sarkand
# Processing Record 9 of Set 9 | san patricio
# Processing Record 10 of Set 9 | lakes entrance
# Processing Record 11 of Set 9 | skogn
# Processing Record 12 of Set 9 | grand forks
# Processing Record 13 of Set 9 | tignere
# Processing Record 14 of Set 9 | thiadiaye
# Processing Record 15 of Set 9 | henties bay
# Processing Record 16 of Set 9 | kapit
# Processing Record 17 of Set 9 | camana
# Processing Record 18 of Set 9 | porto santo
# Processing Record 19 of Set 9 | yanam
# Processing Record 20 of Set 9 | bethel
# Processing Record 21 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 9 | westport
# Processing Record 23 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 9 | namatanai
# Processing Record 25 of Set 9 | timizart
# Processing Record 26 of Set 9 | icod de los vinos
# Processing Record 27 of Set 9 | saintes
# Processing Record 28 of Set 9 | mayo
# Processing Record 29 of Set 9 | seinajoki
# Processing Record 30 of Set 9 | atlantic city
# Processing Record 31 of Set 9 | hovd
# Processing Record 32 of Set 9 | morro bay
# Processing Record 33 of Set 9 | torbay
# Processing Record 34 of Set 9 | metro
# Processing Record 35 of Set 9 | ayan
# Processing Record 36 of Set 9 | zhigansk
# Processing Record 37 of Set 9 | mangrol
# Processing Record 38 of Set 9 | zhitikara
# City not found. Skipping...
# Processing Record 39 of Set 9 | quebec
# Processing Record 40 of Set 9 | santa maria da vitoria
# Processing Record 41 of Set 9 | bozova
# Processing Record 42 of Set 9 | vestmannaeyjar
# Processing Record 43 of Set 9 | soyo
# Processing Record 44 of Set 9 | filingue
# Processing Record 45 of Set 9 | paducah
# Processing Record 46 of Set 9 | aklavik
# Processing Record 47 of Set 9 | alyangula
# Processing Record 48 of Set 9 | xam nua
# Processing Record 49 of Set 9 | general roca
# Processing Record 50 of Set 9 | coralville
# Processing Record 1 of Set 10 | sergeyevka
# Processing Record 2 of Set 10 | lasa
# Processing Record 3 of Set 10 | tazovskiy
# Processing Record 4 of Set 10 | zigos
# Processing Record 5 of Set 10 | vila velha
# Processing Record 6 of Set 10 | pemangkat
# Processing Record 7 of Set 10 | helsingor
# Processing Record 8 of Set 10 | coihaique
# Processing Record 9 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 10 | abu samrah
# Processing Record 11 of Set 10 | tlapacoyan
# Processing Record 12 of Set 10 | bathsheba
# Processing Record 13 of Set 10 | kavieng
# Processing Record 14 of Set 10 | tulum
# Processing Record 15 of Set 10 | snyder
# Processing Record 16 of Set 10 | maragogi
# Processing Record 17 of Set 10 | kamenka
# Processing Record 18 of Set 10 | shingu
# Processing Record 19 of Set 10 | devrek
# Processing Record 20 of Set 10 | porosozero
# Processing Record 21 of Set 10 | chuy
# Processing Record 22 of Set 10 | los llanos de aridane
# Processing Record 23 of Set 10 | vilhena
# Processing Record 24 of Set 10 | teguldet
# Processing Record 25 of Set 10 | sao joao da barra
# Processing Record 26 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 27 of Set 10 | arman
# Processing Record 28 of Set 10 | olafsvik
# Processing Record 29 of Set 10 | jertih
# Processing Record 30 of Set 10 | zgorzelec
# Processing Record 31 of Set 10 | wadi musa
# Processing Record 32 of Set 10 | dakar
# Processing Record 33 of Set 10 | deneysville
# Processing Record 34 of Set 10 | esil
# Processing Record 35 of Set 10 | kanniyakumari
# Processing Record 36 of Set 10 | raudeberg
# Processing Record 37 of Set 10 | nizwa
# Processing Record 38 of Set 10 | road town
# Processing Record 39 of Set 10 | caravelas
# Processing Record 40 of Set 10 | rio grande
# Processing Record 41 of Set 10 | inhambane
# Processing Record 42 of Set 10 | naze
# Processing Record 43 of Set 10 | nemuro
# Processing Record 44 of Set 10 | ntcheu
# Processing Record 45 of Set 10 | kudahuvadhoo
# Processing Record 46 of Set 10 | boyolangu
# Processing Record 47 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 48 of Set 10 | baker city
# Processing Record 49 of Set 10 | the pas
# Processing Record 50 of Set 10 | victoria
# Processing Record 1 of Set 11 | joshimath
# Processing Record 2 of Set 11 | fruitvale
# Processing Record 3 of Set 11 | carauari
# Processing Record 4 of Set 11 | roald
# Processing Record 5 of Set 11 | labuhan
# Processing Record 6 of Set 11 | nagato
# Processing Record 7 of Set 11 | itapua poty
# City not found. Skipping...
# Processing Record 8 of Set 11 | port lincoln
# Processing Record 9 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 10 of Set 11 | enumclaw
# Processing Record 11 of Set 11 | paita
# Processing Record 12 of Set 11 | dourados
# Processing Record 13 of Set 11 | sisimiut
# Processing Record 14 of Set 11 | jalu
# Processing Record 15 of Set 11 | kaitangata
# Processing Record 16 of Set 11 | ca mau
# Processing Record 17 of Set 11 | greymouth
# Processing Record 18 of Set 11 | pisco
# Processing Record 19 of Set 11 | masty
# Processing Record 20 of Set 11 | toora-khem
# Processing Record 21 of Set 11 | santa fe
# Processing Record 22 of Set 11 | pushkinskiye gory
# Processing Record 23 of Set 11 | toyooka
# Processing Record 24 of Set 11 | recodo
# Processing Record 25 of Set 11 | stornoway
# Processing Record 26 of Set 11 | upington
# Processing Record 27 of Set 11 | manyana
# Processing Record 28 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 29 of Set 11 | bria
# Processing Record 30 of Set 11 | moron
# Processing Record 31 of Set 11 | badvel
# Processing Record 32 of Set 11 | yumen
# Processing Record 33 of Set 11 | ilhabela
# Processing Record 34 of Set 11 | dargaville
# Processing Record 35 of Set 11 | huron
# Processing Record 36 of Set 11 | walvis bay
# Processing Record 37 of Set 11 | ilan
# Processing Record 38 of Set 11 | half moon bay
# Processing Record 39 of Set 11 | kurumkan
# Processing Record 40 of Set 11 | saint-leu
# Processing Record 41 of Set 11 | el faiyum
# City not found. Skipping...
# Processing Record 42 of Set 11 | saint anthony
# Processing Record 43 of Set 11 | itarema
# Processing Record 44 of Set 11 | bundaberg
# Processing Record 45 of Set 11 | pirojpur
# Processing Record 46 of Set 11 | burica
# City not found. Skipping...
# Processing Record 47 of Set 11 | den helder
# Processing Record 48 of Set 11 | samarai
# Processing Record 49 of Set 11 | qena
# Processing Record 50 of Set 11 | evans
# Processing Record 1 of Set 12 | devils lake
# Processing Record 2 of Set 12 | valvedditturai
# Processing Record 3 of Set 12 | srandakan
# Processing Record 4 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 6 of Set 12 | tessalit
# Processing Record 7 of Set 12 | bilibino
# Processing Record 8 of Set 12 | boke
# Processing Record 9 of Set 12 | puerto del rosario
# Processing Record 10 of Set 12 | diego de almagro
# Processing Record 11 of Set 12 | tartki
# City not found. Skipping...
# Processing Record 12 of Set 12 | flin flon
# Processing Record 13 of Set 12 | northam
# Processing Record 14 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 15 of Set 12 | bera
# Processing Record 16 of Set 12 | banikoara
# Processing Record 17 of Set 12 | romitan
# Processing Record 18 of Set 12 | abramovka
# Processing Record 19 of Set 12 | marawi
# Processing Record 20 of Set 12 | mehamn
# Processing Record 21 of Set 12 | ukiah
# Processing Record 22 of Set 12 | avera
# Processing Record 23 of Set 12 | sao felix do xingu
# Processing Record 24 of Set 12 | cruzeiro do oeste
# Processing Record 25 of Set 12 | magadan
# Processing Record 26 of Set 12 | luan
# Processing Record 27 of Set 12 | rawson
# Processing Record 28 of Set 12 | springbok
# Processing Record 29 of Set 12 | umarga
# Processing Record 30 of Set 12 | hasaki
# Processing Record 31 of Set 12 | ejido
# Processing Record 32 of Set 12 | chernyshevskiy
# Processing Record 33 of Set 12 | barra do garcas
# Processing Record 34 of Set 12 | port-gentil
# Processing Record 35 of Set 12 | port hawkesbury
# Processing Record 36 of Set 12 | aswan
# Processing Record 37 of Set 12 | faya
# Processing Record 38 of Set 12 | hambantota
# Processing Record 39 of Set 12 | elat
# Processing Record 40 of Set 12 | vao
# Processing Record 41 of Set 12 | charters towers
# Processing Record 42 of Set 12 | jiayuguan
# Processing Record 43 of Set 12 | axim
# Processing Record 44 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 45 of Set 12 | nacala
# Processing Record 46 of Set 12 | ahipara
# Processing Record 47 of Set 12 | kipushi
# Processing Record 48 of Set 12 | kyra
# Processing Record 49 of Set 12 | piacabucu
# Processing Record 50 of Set 12 | seydi
# Processing Record 1 of Set 13 | egvekinot
# Processing Record 2 of Set 13 | shache
# Processing Record 3 of Set 13 | kisangani
# Processing Record 4 of Set 13 | saint-augustin
# Processing Record 5 of Set 13 | russell
# Processing Record 6 of Set 13 | opuwo
# Processing Record 7 of Set 13 | fasa
# Processing Record 8 of Set 13 | mandera
# Processing Record 9 of Set 13 | klaksvik
# Processing Record 10 of Set 13 | palafrugell
# Processing Record 11 of Set 13 | tarakan
# Processing Record 12 of Set 13 | balykshi
# Processing Record 13 of Set 13 | vieques
# Processing Record 14 of Set 13 | tamandare
# Processing Record 15 of Set 13 | asau
# Processing Record 16 of Set 13 | urusha
# Processing Record 17 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 18 of Set 13 | laredo
# Processing Record 19 of Set 13 | valiug
# City not found. Skipping...
# Processing Record 20 of Set 13 | coxim
# Processing Record 21 of Set 13 | gondanglegi
# Processing Record 22 of Set 13 | camopi
# Processing Record 23 of Set 13 | manjacaze
# Processing Record 24 of Set 13 | vuktyl
# Processing Record 25 of Set 13 | phonhong
# Processing Record 26 of Set 13 | tres arroyos
# Processing Record 27 of Set 13 | kharakvasla
# Processing Record 28 of Set 13 | alpena
# Processing Record 29 of Set 13 | port moresby
# Processing Record 30 of Set 13 | abong mbang
# Processing Record 31 of Set 13 | birpur
# Processing Record 32 of Set 13 | ramganj mandi
# Processing Record 33 of Set 13 | damara
# Processing Record 34 of Set 13 | chaman
# Processing Record 35 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 13 | bolpur
# Processing Record 37 of Set 13 | hualmay
# Processing Record 38 of Set 13 | bethanien
# Processing Record 39 of Set 13 | yabassi
# Processing Record 40 of Set 13 | floro
# Processing Record 41 of Set 13 | villarrica
# Processing Record 42 of Set 13 | teahupoo
# Processing Record 43 of Set 13 | nara
# Processing Record 44 of Set 13 | sinjah
# City not found. Skipping...
# Processing Record 45 of Set 13 | rodez
# Processing Record 46 of Set 13 | sabha
# Processing Record 47 of Set 13 | imbituba
# Processing Record 48 of Set 13 | cockburn town
# Processing Record 49 of Set 13 | mishan
# Processing Record 50 of Set 13 | namibe
# Processing Record 1 of Set 14 | alberton
# Processing Record 2 of Set 14 | gostyn
# Processing Record 3 of Set 14 | hamilton
# Processing Record 4 of Set 14 | shizunai
# Processing Record 5 of Set 14 | barra do corda
# Processing Record 6 of Set 14 | tanout
# Processing Record 7 of Set 14 | mbulu
# Processing Record 8 of Set 14 | biloela
# Processing Record 9 of Set 14 | piryion
# City not found. Skipping...
# Processing Record 10 of Set 14 | numi
# City not found. Skipping...
# Processing Record 11 of Set 14 | santa maria
# Processing Record 12 of Set 14 | pandan
# Processing Record 13 of Set 14 | san juan
# Processing Record 14 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 14 | ishigaki
# Processing Record 16 of Set 14 | necochea
# Processing Record 17 of Set 14 | taitung
# Processing Record 18 of Set 14 | caceres
# Processing Record 19 of Set 14 | cachoeira do sul
# Processing Record 20 of Set 14 | miyako
# Processing Record 21 of Set 14 | akyab
# Processing Record 22 of Set 14 | kangaatsiaq
# Processing Record 23 of Set 14 | miri
# Processing Record 24 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 14 | juegang
# Processing Record 26 of Set 14 | kollumerland
# City not found. Skipping...
# Processing Record 27 of Set 14 | porbandar
# Processing Record 28 of Set 14 | pangnirtung
# Processing Record 29 of Set 14 | porto novo
# Processing Record 30 of Set 14 | samfya
# Processing Record 31 of Set 14 | ajdabiya
# Processing Record 32 of Set 14 | aksha
# Processing Record 33 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 34 of Set 14 | ayni
# Processing Record 35 of Set 14 | hemnesberget
# Processing Record 36 of Set 14 | bose
# Processing Record 37 of Set 14 | sohag
# Processing Record 38 of Set 14 | cabra
# Processing Record 39 of Set 14 | mujiayingzi
# Processing Record 40 of Set 14 | atar
# Processing Record 41 of Set 14 | bayugan
# Processing Record 42 of Set 14 | te anau
# Processing Record 43 of Set 14 | mawlaik
# Processing Record 44 of Set 14 | marquette
# Processing Record 45 of Set 14 | diffa
# Processing Record 46 of Set 14 | clyde river
# Processing Record 47 of Set 14 | aktash
# Processing Record 48 of Set 14 | nevelsk
# Processing Record 49 of Set 14 | mildura
# Processing Record 50 of Set 14 | douglas
# Processing Record 1 of Set 15 | gallup
# Processing Record 2 of Set 15 | aguimes
# Processing Record 3 of Set 15 | bugarama
# Processing Record 4 of Set 15 | mutoko
# Processing Record 5 of Set 15 | xichang
# Processing Record 6 of Set 15 | ust-karsk
# Processing Record 7 of Set 15 | surt
# Processing Record 8 of Set 15 | tagusao
# Processing Record 9 of Set 15 | kawalu
# Processing Record 10 of Set 15 | barao de melgaco
# Processing Record 11 of Set 15 | somerset west
# Processing Record 12 of Set 15 | vadso
# Processing Record 13 of Set 15 | talawdi
# City not found. Skipping...
# Processing Record 14 of Set 15 | kabinda
# Processing Record 15 of Set 15 | burkburnett
# Processing Record 16 of Set 15 | rincon de la victoria
# Processing Record 17 of Set 15 | tukrah
# Processing Record 18 of Set 15 | mecca
# Processing Record 19 of Set 15 | sensuntepeque
# Processing Record 20 of Set 15 | barber
# Processing Record 21 of Set 15 | tarboro
# Processing Record 22 of Set 15 | alugan
# Processing Record 23 of Set 15 | anar darreh
# City not found. Skipping...
# Processing Record 24 of Set 15 | rabo de peixe
# Processing Record 25 of Set 15 | aliwal north
# Processing Record 26 of Set 15 | kali vrisi
# Processing Record 27 of Set 15 | timmins
# Processing Record 28 of Set 15 | kankon
# Processing Record 29 of Set 15 | alexandria
# Processing Record 30 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 15 | samana
# Processing Record 32 of Set 15 | baghdad
# Processing Record 33 of Set 15 | lejanias
# Processing Record 34 of Set 15 | ketchikan
# Processing Record 35 of Set 15 | wellington
# Processing Record 36 of Set 15 | magnolia
# Processing Record 37 of Set 15 | andros town
# Processing Record 38 of Set 15 | taguatinga
# Processing Record 39 of Set 15 | dubbo
# Processing Record 40 of Set 15 | husavik
# Processing Record 41 of Set 15 | buzmeyin
# Processing Record 42 of Set 15 | nuristan
# Processing Record 43 of Set 15 | great falls
# Processing Record 44 of Set 15 | san luis
# Processing Record 45 of Set 15 | tabon
# Processing Record 46 of Set 15 | marsh harbour
# Processing Record 47 of Set 15 | moerai
# Processing Record 48 of Set 15 | seoul
# Processing Record 49 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 50 of Set 15 | fresnillo
# Processing Record 1 of Set 16 | teocuitatlan de corona
# Processing Record 2 of Set 16 | bilari
# Processing Record 3 of Set 16 | kavarskas
# Processing Record 4 of Set 16 | kashi
# Processing Record 5 of Set 16 | pochutla
# Processing Record 6 of Set 16 | gat
# Processing Record 7 of Set 16 | tilichiki
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 696

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Port Macquarie      AU -31.4333  152.9167     67.89        94
# 1           Mar Del Plata      AR -38.0023  -57.5575     55.87        72
# 2                 Rikitea      PF -23.1203 -134.9692     77.40        75
# 3               Fairbanks      US  64.8378 -147.7164     44.94        79
# 4                  Hobart      AU -42.8794  147.3294     49.01        94
# 5             Grand Gaube      MU -20.0064   57.6608     73.80        82
# 6            Komsomolskiy      UZ  40.4272   71.7189     66.92        55
# 7  Sao Miguel Do Araguaia      BR -13.2750  -50.1628     80.10        43
# 8            Norman Wells      CA  65.2820 -126.8329     53.64        35
# 9            Abrau-Dyurso      RU  44.6900   37.5900     47.66        86
#
#    Cloudiness  Wind Speed Weather Description
# 0         100        1.14     overcast clouds
# 1           0       11.99           clear sky
# 2          10       20.11          light rain
# 3          75        5.75       broken clouds
# 4           0        9.22           clear sky
# 5          12        1.99          few clouds
# 6         100        4.61     overcast clouds
# 7          24        0.89          few clouds
# 8          20        6.91          few clouds
# 9          21        9.42          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
